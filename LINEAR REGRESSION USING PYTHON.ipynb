# %% [markdown]
# <a href="https://colab.research.google.com/github/fatih-ali/my_project/blob/main/LINEAR%20REGRESSION%20USING%20PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salary_dataset.csv')
print(data)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
plt.scatter(data.YearsExperience, data.Salary)

# %%
def loss_function(m, b, points):
    total_error = 0
    for i in range(len(points)):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary
        total_error += (y - (m * x + b)) ** 2

# %%
def gradient_descent(m_now, b_now, points, L):
    m_grad = 0
    b_grad = 0
    n = len(points)

    for i in range(n):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary

        m_grad += (-2/n) * x * (y - (m_now * x + b_now))
        b_grad += (-2/n) * (y - (m_now * x + b_now))

    # Update parameters
    m = m_now - L * m_grad
    b = b_now - L * b_grad
    return m, b

# %%
m = 0
b = 0
L = 0.001
epochs = 300

for i in range(epochs):
  if i % 50 == 0:
    print(f"Epoch: {i}")
  m, b = gradient_descent(m, b, data, L)

print(m, b)
# Out:
# Epoch: 0
# Epoch: 50
# Epoch: 100
# Epoch: 150
# Epoch: 200
# Epoch: 250
# 12429.608750911455 4546.335717082644

# %%
plt.scatter(data.YearsExperience, data.Salary,color = "black")
import numpy as np
x_values = np.linspace(1.2, 10.6, 100) # Generate 100 points between 1.2 and 10.6
y_values = m * x_values + b
plt.plot(x_values, y_values, color = "red")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs. Years of Experience")
plt.show()
